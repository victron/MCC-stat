# %% [markdown]
# TODO:
# + easy table and column selection [DONE: can be better, but ok for now]
#
#
# # common section

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import logging

# %%
logger = logging.getLogger()
logger.setLevel(logging.ERROR)

# %%
# set default figsize
import matplotlib as mpl
width, height = 15, 3 # example with 15x6 inches
# mpl.rcParams['figure.figsize'] = [width, height]
sns.set(rc={'figure.figsize':(width, height)})

# %%
# pandas settings
pd.set_option('display.max_columns', 10000)
pd.set_option('display.precision', 8)

# %%
# %run ./stat_help.ipynb

# %%
# environment information
DATAs = r'D:\Viktor\OneDrive - Microsoft\_Affirmmed\_CUBIC\FW__Cubic_Dublin_MCC_Monitoring__09_03\stat'

# %% [markdown]
# create dictionary of tables

# %%
stat = stat_frames(DATAs, "2022-04-21T10:00", "2022-04-23T10:00", tz="UTC")
# Out:
# not stat file pm_2022-04-22.tar
# selectSortFiles time= 0:00:12.153295
# put in dfs time= 0:05:28.642348

# %% [markdown]
# ### save to pickle

# %%
# for k, v in stat.items():
#     v.to_pickle(k+'.pkl')

# %% [markdown]
# list tables

# %%
[k for k in stat.keys()]
# Out:
# ['ABRRATELIMITINGVIDEOSEGMENTSTATSCHASSIS',
#  'ABRRATELIMITINGVIDEOSESSIONSTATSCHASSIS',
#  'APNCALLPERF',
#  'APNCALLPERFSTATSGRID',
#  'BEARERUSAGESTATS',
#  'CONTENTCACHESUMMARYSTATS',
#  'CONTENTCACHESUMMARYSTATSCHASSIS',
#  'CONTENTDNSSERVERDETAILSTATSCHASSIS',
#  'CONTENTDNSSERVERDETAILSTATS_KPI',
#  'CONTENTDNSSERVERSUMMARYSTATSCHASSIS',
#  'CONTENTDNSSERVERSUMMARYSTATSSLOT',
#  'CONTENTDNSSERVERSUMMARYSTATS_KPI',
#  'CONTENTFILTERCONTENTCATEGORIZATIONSTATSSLOT',
#  'CONTENTFILTERCONTENTCATEGORIZATIONSTATSSLOT_KPI',
#  'CONTENTFILTERSUMMARY',
#  'CONTENTFILTERSUMMARYSTATSCHASSIS',
#  'CONTENTHTTPCACHESTATSCHASSIS',
#  'CONTENTHTTPPROXYCOMPRESSIONSTATS',
#  'CONTENTHTTPPROXYCOMPRESSIONSTATSGRID',
#  'CONTENTHTTPPROXYCONNECTIONSTATSCHASSIS',
#  'CONTENTHTTPPROXYDETAILSTATSCHASSIS',
#  'CONTENTHTTPPROXYFAILSTATSCHASSIS',
#  'CONTENTHTTPPROXYLATENCYSTATSCHASSIS',
#  'CONTENTHTTPPROXYOVERLOADCONTROLSTATSCHASSIS',
#  'CONTENTHTTPPROXYPREMPTDNSSTATSGRID',
#  'CONTENTHTTPPROXYSUMMARY',
#  'CONTENTHTTPPROXYSUMMARYSTATSCHASSIS',
#  'CONTENTHTTPPROXYTCPOPTZSTATSSLOT',
#  'CONTENTHTTPPROXYWEBIMAGEOPTDETAILSTATSGRID',
#  'CONTENTHTTPPROXYWEBIMAGEOPTSUMMARYSTATS',
#  'CONTENTHTTPPROXYWEBIMAGEOPTSUMMARYSTATSGRID',
#  'CONTENTHTTPSERVERSUMMARYSTATSCHASSIS',
#  'CONTENTLDAPSTATSSUMGRID',
#  'CONTENTSTIDETAILSTATSGRID',
#  'CONTENTVAOFFLINETRANSCODINGSUMMARYSTATS',
#  'CONTENTVAOFFLINETRANSCODINGSUMMARYSTATSCHASSIS',
#  'CONTENTVAONLINETRANSCODINGSUMMARYSTATS',
#  'CONTENTVAONLINETRANSCODINGSUMMARYSTATSCHASSIS',
#  'CONTENTWAPGWSTATSGRID',
#  'DIAMETER',
#  'DIAMETERRESULTCODESTATSPEER',
#  'DIAMETERSTATSPEER',
#  'DISK_STATS',
#  'DNSRESOLUTIONSTATS',
#  'DPIGENERAL',
#  'DPIGENERALGRID',
#  'DPITETHERINGGRID',
#  'DPIWEBHTTPTRANSACTIONSGRID',
#  'EDR_BEARER_STATS',
#  'EDR_FLOW_STATS',
#  'EDR_HTTP_STATS',
#  'EDR_PILOT_STATS',
#  'EDR_RTT_STATS',
#  'EDR_SERVER_STATS',
#  'EDR_SESSION_STATS',
#  'EMSDPIAPPLICATIONATTRSGRID',
#  'EMSDPIFLOWATTRGRID',
#  'EMSDPIPROTOCOLATTRSGRID',
#  'EMSDPITDCIGRID',
#  'EMSGWQCIARP',
#  'EMSGWQCIARPSTATS',
#  'GEOREDPERFSTATSGRID',
#  'GWGTPMESSAGE',
#  'GWGTPMESSAGESTATS',
#  'HTTPPROXYMEDIATYPEBYTESCHASSIS',
#  'HTTPPROXYOPTIMIZATIONSAVINGS',
#  'HTTPPROXYTOLLFREEDATASUMMARYSTATSCHASSIS',
#  'INTERFACESTATISTICS',
#  'INTERFACESTATISTICSGRID',
#  'INTERFACEUSAGESTATS',
#  'IPFRAGMODULEPERFSTATS',
#  'IPFRAGMODULEPERFSTATSCHASSIS',
#  'NATPERFCLUSTERLEVELMODULESTATS',
#  'NETWORKCONTEXTSTATISTICS',
#  'NETWORKCONTEXTSTATISTICSGRID',
#  'NETWORKCONTEXTUEIPSUBPOOLSTATISTICS',
#  'NETWORKCONTEXTUEPOOLSTATISTICS',
#  'PCSCFADDRESSSTATS',
#  'PGW',
#  'PGWCALLPERFSTATSGRID',
#  'PGWPROCEDURE',
#  'PGWPROCEDUREGRID',
#  'PORT_STATS',
#  'PROXYBUFFERSTATS',
#  'PROXYBUFFERSTATSCHASSIS',
#  'PROXYBUFFERSTATSSLOT',
#  'RADIUSPROCEDURE',
#  'RADIUSPROCEDUREPEER',
#  'RADIUSPROCEDURESTATS',
#  'RADIUSPROCEDURESTATSPEER',
#  'SAEGWPGWPROCEDURE',
#  'SAEGWPGWPROCEDUREGRID',
#  'SERVERPLUGINSTATSCHASSIS',
#  'SERVERPLUGINSTATSCHASSIS_KPI',
#  'SERVICEDATACONTAINERSTATS',
#  'SIPADVANCEDGRID',
#  'SIPBASICGRID',
#  'SLOT_STATS',
#  'SYSTEMCPUSTATISTICS',
#  'SYSTEMCPUSTATISTICSCORELEVEL',
#  'SYSTEMCPUSTATISTICSCPULEVEL',
#  'SYSTEMLOADSTATISTICS',
#  'SYSTEMMEMORYSTATISTICS',
#  'SYSTEMMEMORYSTATISTICSCPULEVEL',
#  'SYSTEMPFMSTATISTICS',
#  'SYSTEM_NODE_UPTIME',
#  'SYSTEM_UPTIME',
#  'TASK_STATS',
#  'TCPMEASUREMENTSSERVERSIDESTATSCHASSIS',
#  'TCPMEASUREMENTSSTATSTAC',
#  'TCPMEASUREMENTSSUMMARYSTATS',
#  'TCPMEASUREMENTSSUMMARYSTATSCHASSIS',
#  'TCPPERFORMANCESTATSSLOT',
#  'TCPREORDERPERFSTATSCHASSIS',
#  'TCPREORDERPERFSTATSSLOT',
#  'TCPSPLICINGRATELIMITINGSTATSCHASSIS',
#  'TCPSPLICINGSTATSCONNECTION',
#  'TCPSPLICINGSTATSCONNECTIONCHASSIS',
#  'TCPSPLICINGSTATSCONNECTIONSLOT',
#  'TCPSPLICINGSTATSDETAILCHASSIS',
#  'TCPSPLICINGSTATSDNSCHASSIS',
#  'TCPSPLICINGSTATSFAILURECHASSIS',
#  'TCPSPLICINGSTATSSUMMARY',
#  'TCPSPLICINGSTATSSUMMARYCHASSIS',
#  'UDPPROXYSTATSCONNECTIONCHASSIS',
#  'UDPPROXYSTATSCONNECTIONCHASSIS_KPI',
#  'UDPPROXYSTATSDETAILCHASSIS',
#  'UDPPROXYSTATSDNSCHASSIS',
#  'UDPPROXYSTATSFAILURECHASSIS',
#  'UDPPROXYSTATSQUICCHASSIS',
#  'UDPPROXYSTATSQUICCHASSIS_KPI',
#  'UDPPROXYSTATSRATELIMITINGCHASSIS',
#  'UDPPROXYSTATSSUMMARYCHASSIS',
#  'UDPPROXYSTATSSUMMARYCHASSIS_KPI',
#  'UPLANEDNSSTATS',
#  'VASOPTIMIZATIONSAVINGS',
#  'WORKFLOWPERFSTATSCHASSIS',
#  'WORKFLOWPERFSTATSSLOT']

# %% [markdown]
# # Corr. to selected counter
# ## prepare counter

# %%
pgwcall = stat['PGWCALLPERFSTATSGRID']
pgwcall.head(1)
# Out:
#                              resourceid zone_name      pgw_name  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00  DUB1-PGW-110   default  PGW-DUB-Test
#
#                            NumCurrentSessions  NumBearers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   1           1
#
#                            NumCreateSessionAttempt  NumCreateSessionAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      0.0                     0.0
#
#                            NumCreateSessionReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0
#
#                            NumCreateSessionRejectMalformedReq  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            NumCreateSessionRejectUnknownApn  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumCreateSessionRejectRsrcUnavailable  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                    0.0
#
#                            NumCreateSessionRejectServiceNotSupported  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                        0.0
#
#                            NumCreateSessionRejectSystemFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumCreateSessionRejectMisc  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumDeleteSessionAttempt  NumDeleteSessionAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      0.0                     0.0
#
#                            NumDeleteSessionReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0
#
#                            NumUEInitDedBearerActAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumUEInitDedBearerActAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumUEInitDedBearerActReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumPGWInitDedBearerActAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumPGWInitDedBearerActAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumPGWInitDedBearerActReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumMMEInitDedBearerDeactAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumMMEInitDedBearerDeactAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumMMEInitDedBearerDeactReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumUEInitDedBearerDeactAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumUEInitDedBearerDeactAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumUEInitDedBearerDeactReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumPGWInitDedBearerDeactAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumPGWInitDedBearerDeactAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumPGWInitDedBearerDeactReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumModifyBearerCmdAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0.0
#
#                            NumModifyBearerCmdReject  NumUpdateBearerAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0                     0.0
#
#                            NumUpdateBearerAccept  NumUpdateBearerReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0                    0.0
#
#                            NumModifyBearerAttempt  NumModifyBearerAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0                    0.0
#
#                            NumModifyBearerReject  NumCreatePdpAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0                  0.0
#
#                            NumCreatePdpAccept  NumCreatePdpReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 0.0                 0.0
#
#                            NumCreatePdpRejectMalformedReq  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumCreatePdpRejectUnknownApn  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumCreatePdpRejectRsrcUnavailable  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumCreatePdpRejectServiceNotSupported  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                    0.0
#
#                            NumCreatePdpRejectSystemFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumCreatePdpRejectMisc  NumDeletePdpAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0                  0.0
#
#                            NumDeletePdpAccept  NumDeletePdpReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 0.0                 0.0
#
#                            NumUEInitSecPdpActAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0.0
#
#                            NumUEInitSecPdpActAccept  NumUEInitSecPdpActReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0                       0.0
#
#                            NumGGSNInitSecPdpActAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumGGSNInitSecPdpActAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumGGSNInitSecPdpActReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumSGSNInitSecPdpDeactAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumSGSNInitSecPdpDeactAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumSGSNInitSecPdpDeactReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumUEInitSecPdpDeactAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumUEInitSecPdpDeactAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumUEInitSecPdpDeactReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumGGSNInitSecPdpDeactAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumGGSNInitSecPdpDeactAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumGGSNInitSecPdpDeactReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumSGSNInitUpdatePdpAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumSGSNInitUpdatePdpAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumSGSNInitUpdatePdpReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumGGSNInitUpdatePdpAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumGGSNInitUpdatePdpAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumGGSNInitUpdatePdpReject  NumLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0                    0.0
#
#                            NumLocalCloseAttemptsAccepted  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumIdleDurationExceededCloses  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumMaximalDurationExceededCloses  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumOperatorInitiatedCloses  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumActiveCurrentSessions  NumIdleCurrentSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         1                       0
#
#                            IntervalPeakCurrentSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            1
#
#                            IntervalPeakActiveCurrentSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  1
#
#                            IntervalPeakIdleCurrentSessions  NumDefaultBearers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0                  1
#
#                            NumDedicatedBearers  IntervalPeakBearers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0                    1
#
#                            IntervalPeakDefaultBearers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           1
#
#                            IntervalPeakDedicatedBearers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0
#
#                            NumDhcpReleaseLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumTraceSessionActivationAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0
#
#                            NumTraceSessionActivationAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0
#
#                            NumTraceSessionDeactivationAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0
#
#                            NumTraceSessionDeactivationAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0
#
#                            NumDhcpTimeoutLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumDhcpLeaseExpiryLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumRadiusDisconnectLocalCloses  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumRatTypeUtranSessions  NumRatTypeGeranSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0                        0
#
#                            NumRatTypeWlanSessions  NumRatTypeGanSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0                      0
#
#                            NumRatTypeHspaEvoSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0
#
#                            NumRatTypeEUtranSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         1
#
#                            NumRatTypeVirtualSessions  NumGzSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0              0
#
#                            NumUniqueSubscribers  NumColocatedSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     1                     0
#
#                            NumIpv4PdnSessions  NumIpv6PdnSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   1                   0
#
#                            NumIpv4v6PdnSessions  NumRatHandovers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0              0.0
#
#                            NumSessionsSetupWithDefaultPolicy  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumActiveSessionsWithDefaultPolicy  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0
#
#                            NumActiveGxReplaySessionsAwaitingPcrfRejoin  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                            0
#
#                            NumGxReplaySessionsTerminated  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumDuplicateSessionLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                    0.0
#
#                            NumCtrlTeidLookupFailures  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0.0
#
#                            NumChangeNotificationReqAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumChangeNotificationReqAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumChangeNotificationReqReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumChangeNotificationReqRejectMalformedReq  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                         0.0
#
#                            NumChangeNotificationReqRejectUnknownApn  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumChangeNotificationReqRejectRsrcUnavailable  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                            0.0
#
#                            NumChangeNotificationReqRejectServiceNotSupported  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            NumChangeNotificationReqRejectSystemFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                          0.0
#
#                            NumChangeNotificationReqRejectMisc  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            NumChangeNotificationReqDrop  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumWfTeidCollisionLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumPcrfRejoinSuccess  NumErrorIndicationsProcessed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                           0.0
#
#                            NumErrorIndicationLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumErrorIndicationBearerDeactivation  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumAwaitCoATimeoutLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumGtppCdrSent  NumGtppCdrRespSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00             0.0                    0.0
#
#                            NumGtppCdrRespFailure  NumGtppCdrRespTimeout  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0                    0.0
#
#                            NumPcrfInitiatedCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumOcsInitiatedCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumTotalBearersSetupFail  NumCurrentBearersQci1  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0                      0
#
#                            NumCurrentBearersQci2  NumCurrentBearersQci3  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      0                      0
#
#                            NumCurrentBearersQci4  NumCurrentBearersQci5  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      0                      0
#
#                            NumCurrentBearersQci6  NumCurrentBearersQci7  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      0                      0
#
#                            NumCurrentBearersQci8  NumCurrentBearersQci9  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      1                      0
#
#                            NumCurrentBearersQciOther  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0
#
#                            NumTotalBearersSetupSuccessQci1  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci2  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci3  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci4  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci5  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci6  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci7  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci8  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQci9  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumTotalBearersSetupSuccessQciOther  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumTotalBearersSetupFailQci1  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci2  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci3  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci4  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci5  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci6  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci7  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci8  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQci9  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumTotalBearersSetupFailQciOther  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumSaegwCurrentSessions  NumSaegwCurrentBearers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0                       0
#
#                            NumSaegwTotalBearersSetupSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumSaegwTotalBearersSetupFail  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumSaegwCurrentBearersQci1  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci2  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci3  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci4  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci5  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci6  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci7  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci8  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQci9  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0
#
#                            NumSaegwCurrentBearersQciOther  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0
#
#                            NumSaegwTotalBearersSetupSuccessQci1  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci2  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci3  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci4  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci5  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci6  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci7  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci8  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQci9  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumSaegwTotalBearersSetupSuccessQciOther  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumSaegwTotalBearersSetupFailQci1  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci2  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci3  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci4  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci5  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci6  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci7  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci8  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQci9  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumSaegwTotalBearersSetupFailQciOther  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                    0.0
#
#                            NumL2tpGwSessionDeleteAttempts  NumUplinkPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0              21.0
#
#                            NumUplinkBytes  NumUplinkDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00          1294.0                   0.0
#
#                            NumUplinkDropBytes  NumDownlinkPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 0.0                19.0
#
#                            NumDownlinkBytes  NumDownlinkDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00            1964.0                     0.0
#
#                            NumDownlinkDropBytes  NumSuspendNotification  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                     0.0
#
#                            NumSuspendNotificationAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumSuspendNotificationReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumResumeNotification  NumResumeNotificationAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0                          0.0
#
#                            NumResumeNotificationReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumUplinkSuspendDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumUplinkSuspendDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0.0
#
#                            NumDownlinkSuspendDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumDownlinkSuspendDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumDeletePdpDropTearDownIndMissingOneBearerOnly  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                              0.0
#
#                            NumDeletePdpDropTearDownIndMissingForDefaultBearer  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            NumSessionsSetupWithDefaultGyQuota  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            NumActiveSessionsWithDefaultGyQuota  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                    0
#
#                            NumActiveGySessionsAwaitingOcsRejoin  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                     0
#
#                            NumOcsGyRejoinSuccess  NumDefaultGyQuotaReapplied  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0                         0.0
#
#                            NumDefaultGyQuotaAppliedCcruFailure  NumGxSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0              1
#
#                            NumGySessions  NumGyDownGyRejoinTimerRestarted  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00              0                              0.0
#
#                            NumS6bInitiatedCloseAttempts  NumActiveS6bSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0                   NaN
#
#                            DefaultGyUplinkBytes  DefaultGyDownlinkBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                     0.0
#
#                            NumIgnoreSprRadiusFailureSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                0.0
#
#                            NumBearerIdleDurationExceededCloses  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumOfActiveS6bSessions  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0
#
#                            NumInterAccessHOReqNoSessionReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            NumInterAccessHOReqNoSessionAccept  NumDnsAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0             0.0
#
#                            NumDnsSendSuccess  NumDnsSendFailedNoConfig  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                0.0                       0.0
#
#                            NumDnsFailedMisc  NumDnsResponses  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00               0.0              0.0
#
#                            NumDnsResponseSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0
#
#                            NumDnsResponseFailNoResponse  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumDnsResponseFailNoName  NumDnsResponseFailNoData  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0                       0.0
#
#                            NumDnsResponseFailMisc  NumPcoPcscfDefaultFqdnUsed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0                         0.0
#
#                            NumPcoPcscfTableUsed  NumSprAuthReqAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                   0.0
#
#                            NumSprAuthReqAccept  NumSprAuthReqReject  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                  0.0                  0.0
#
#                            NumSprAuthReqTimeout  NumAcctStartReqAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                     0.0
#
#                            NumAcctStartReqAccept  NumAcctStartReqTimeout  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    0.0                     0.0
#
#                            NumAcctInterimUpdReqAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumAcctInterimUpdReqAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumAcctInterimUpdReqTimeout  NumAcctStopReqAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0                    0.0
#
#                            NumAcctStopReqAccept  NumAcctStopReqTimeout  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                    0.0
#
#                            NumTTLExcdDropPackets  NumTTLExcdDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    NaN                  NaN
#
#                            NumFragSendPackets  NumFragSendBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 NaN               NaN
#
#                            NumFragFailPackets  NumFragFailBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 NaN               NaN
#
#                            NumUplinkAclDropPackets  NumUplinkAclDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      NaN                    NaN
#
#                            NumDownlinkAclDropPackets  NumDownlinkAclDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        NaN                      NaN
#
#                            NumBadSrcAddrDropPackets  NumBadSrcAddrDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       NaN                     NaN
#
#                            NumNoTFTDropPackets  NumNoTFTDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                  NaN                NaN
#
#                            NumBadUEAddrDropPackets  NumBadUEAddrDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                      NaN                    NaN
#
#                            NumMTUDropPackets  NumMTUDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                NaN              NaN
#
#                            NumNoRouteDropPackets  NumNoRouteDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                    NaN                  NaN
#
#                            NumNoEgressIntfDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         NaN
#
#                            NumNoEgressIntfDropBytes  NumberTTLExcdDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       NaN                       0.0
#
#                            NumberTTLExcdDropBytes  NumberFragSendPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0                    0.0
#
#                            NumberFragSendBytes  NumberFragFailPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                  0.0                    0.0
#
#                            NumberFragFailBytes  NumberUplinkAclDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                  0.0                         0.0
#
#                            NumberUplinkAclDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0
#
#                            NumberDownlinkAclDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumberDownlinkAclDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                         0.0
#
#                            NumberBadSrcAddrDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumberBadSrcAddrDropBytes  NumberNoTFTDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0.0                     0.0
#
#                            NumberNoTFTDropBytes  NumberBadUEAddrDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                         0.0
#
#                            NumberBadUEAddrDropBytes  NumberMTUDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0                   0.0
#
#                            NumberMTUDropBytes  NumberNoRouteDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 0.0                       0.0
#
#                            NumberNoRouteDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0
#
#                            NumberNoEgressIntfDropPackets  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumberNoEgressIntfDropBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumCurrentSessionsGnGeran  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0
#
#                            NumCurrentSessionsGnUtran  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0
#
#                            NumCurrentSessionsS5S8Geran  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0
#
#                            NumCurrentSessionsS5S8Utran  \
# ...
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            NumDnsCacheHits  NumDnsCacheHitsNaptr  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00              0.0                   0.0
#
#                            NumDnsCacheHitsSrv  NumDnsCacheHitsA  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                 0.0               0.0
#
#                            ConnectedDeviceFlows  ConnectedDeviceUlPkts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                    0.0
#
#                            ConnectedDeviceUlBytes  ConnectedDeviceDlPkts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0                    0.0
#
#                            ConnectedDeviceDlBytes  TetheredDeviceFlows  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0                  0.0
#
#                            TetheredDeviceUlPkts  TetheredDeviceUlBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                    0.0
#
#                            TetheredDeviceDlPkts  TetheredDeviceDlBytes  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                   0.0                    0.0
#
#                            TetheringEntitledFlows  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0
#
#                            TetheringEntitledUplinkPacketsPassed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            TetheringEntitledUplinkBytesPassed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            TetheringEntitledDownlinkPacketsPassed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                     0.0
#
#                            TetheringEntitledDownlinkBytesPassed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            TetheredFlowsDetectedUsingTtl  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            TetheredFlowsDetectedUsingUserAgent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumCreateSessionRejectTamFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            NumCreatePdpRejectTamFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            NumCreateCupsSessionAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumCreateCupsSessionSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumCreateCupsSessionFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumModifyCupsSessionAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumModifyCupsSessionSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumModifyCupsSessionFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumDeleteCupsSessionAttempt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumDeleteCupsSessionSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumDeleteCupsSessionFailure  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumLocalCloseSessionMonitor  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumCurrentCupsSessions  NumPgwTriggeredQosUpdate  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0                       0.0
#
#                            NumSessionsEstablishedWithExistingImsiAndApn  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                           0.0
#
#                            NumPGWInitDedBearerActPartialAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumUpdateBearerPartialAccept  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                           0.0
#
#                            TetheredFlowsDetectedUsingTcpIpFingerprinting  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                            0.0
#
#                            NumDnsResponseFailTimeout  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                        0.0
#
#                            NumDnsResponseDropNoIntf  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                       0.0
#
#                            NumDnsResponseDropNoSession  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                          0.0
#
#                            NumDnsResponseDropNoPdnSession  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumSessionPendedForDns  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     0.0
#
#                            NumSessionPendedForDnsSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumSessionPendedForDnsTimeout  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            num3gppToNon3gppDelayedHandovers  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                               0.0
#
#                            num3gppToNon3gppDelayedHandoverCompletedOnFirstUlPkt  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            num3gppToNon3gppDelayedHandoverCompletedOnTimerExpiry  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            num3gppToNon3gppDelayedHandoverCompletedOnBackToBackHo  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            num3gppToNon3gppDelayedHandoverCompletedOnOtherEvent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            NumApplicationStartNotificationsRcvd  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumApplicationStopNotificationsRcvd  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumGxApplicationStartNotificationsSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                        0.0
#
#                            NumGxApplicationStartNotificationsFailed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumGxApplicationStopNotificationsSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumGxApplicationStopNotificationsFailed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                      0.0
#
#                            NumSessionMonitorModificationsSent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            NumSdApplicationStartNotificationsSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                        0.0
#
#                            NumSdApplicationStartNotificationsFailed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumSdApplicationStopNotificationsSuccess  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumSdApplicationStopNotificationsFailed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                      0.0
#
#                            NumLocalClosePcrfDownSessionHoldTime  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumCreateSessionRejectsAccountingOnPending  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                         0.0
#
#                            NumCreatePdpContextsRejectsAccountingOnPending  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                             0.0
#
#                            NumCreateSessionRejectChangeSessionToColocatedFailed  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                                0.0
#
#                            NumCreateSessionRejectsOverload  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumCreateBearerRejectsOverload  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            NumManifestServerRequestsSent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            NumManifestServerResponsesRcvd  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                             0.0
#
#                            TetheredFlowsDetectedUsingGquicUserAgent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            TetheredFlowsReportedUsingTtl  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                            0.0
#
#                            TetheredFlowsReportedUsingUserAgent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            TetheredFlowsReportedUsingTcpIpFingerprinting  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                            0.0
#
#                            TetheredFlowsReportedUsingGquicUserAgent  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                       0.0
#
#                            NumCreateSessionRejectsOverloadMinor  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumCreateSessionRejectsOverloadMajor  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                   0.0
#
#                            NumCreateSessionRejectsOverloadCritical  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                      0.0
#
#                            NumCreateSessionRejectsOverloadMCDSync  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                     0.0
#
#                            NumCreateBearerRejectsOverloadMinor  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumCreateBearerRejectsOverloadMajor  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumCreateBearerRejectsOverloadCritical  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                     0.0
#
#                            NumCreateBearerRejectsOverloadMCDSync  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                    0.0
#
#                            NumCreateSessionRejectNoServiceRule  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                  0.0
#
#                            NumNoServiceRuleLocalCloseAttempts  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                                 0.0
#
#                            NumCreatePdpRejectNoServiceRule  \
# #timeofcollection
# 2022-04-21 10:05:00+00:00                              0.0
#
#                            NumLocalClosePfcpError  NumLocalCloseUplaneError
# #timeofcollection
# 2022-04-21 10:05:00+00:00                     NaN                       0.0

# %%
# list available pgw_name
pgwcall.groupby(by=['pgw_name']).size()
# Out:
# pgw_name
# PGW-DUB-Test              289
# PGW-EE_01                 289
# PGW-EE_Test               289
# PGW-GEO-Test              289
# PGW-IBASIS_2              289
# PGW-IBASIS_3_TELE2        289
# PGW-IBASIS_4_AIS          289
# PGW-IBASIS_CUBIC-29506    289
# PGW-IBASIS_CUBIC-72446    289
# PGW-IBASIS_CUBIC-90173    289
# PGW-OrangeF               289
# PGW-OrangeF-RS            289
# PGW-VF_NL                 289
# dtype: int64

# %%
IBASIS2 = pgwcall.groupby(by=['pgw_name']).get_group('PGW-IBASIS_2')
IBASIS2.index.is_unique
# Out:
# True

# %%
IBASIS2['NumCurrentSessions'].plot()
# Out:
# <AxesSubplot:xlabel='#timeofcollection'>

# %%
# taking interesting period of time
IBASIS21 = IBASIS2['NumCurrentSessions'].loc['2022-04-21 21:00':]
IBASIS21.plot()
# Out:
# <AxesSubplot:xlabel='#timeofcollection'>

# %% [markdown]
# ## walk via all df and create corr df and stat_unique table
# stat_unique - is a dictionary of df converted to unique datetime index and muldiindex columns

# %%
# taking interesting period of time for all tables
stat21 = {}
for k, v in stat.items():
    stat21[k] = v.loc['2022-04-21 21:00':]

# %%
corr_all, stat_unique = corrAll(stat21, IBASIS21)
# Out:
# (21015, 3)138, finished WORKFLOWPERFSTATSSLOTSISSIS_KPISPISISISASSISSI

# %% [markdown]
# ## review corr df and plot interesting plots

# %%
# corr_all[np.abs(top_corr_all['corr']) > .99]
# top_corr_all.shape
corr_all[(corr_all['table'] == 'SYSTEMPFMSTATISTICS') & (np.abs(corr_all['corr']) > .7)]
# Out:
#                                  index        corr                table
# 17236  (baserx_avg_1_min_mbps_sec, 14) -0.72295802  SYSTEMPFMSTATISTICS
# 17237  (baserx_avg_1_min_mbps_sec, 15) -0.72209606  SYSTEMPFMSTATISTICS
# 17238  (baserx_avg_1_min_mbps_sec, 16) -0.75458224  SYSTEMPFMSTATISTICS
# 17239  (baserx_avg_1_min_mbps_sec, 19) -0.71055424  SYSTEMPFMSTATISTICS
# 17248   (baserx_avg_1_min_mbps_sec, 4) -0.72188664  SYSTEMPFMSTATISTICS
# 17252   (baserx_avg_1_min_mbps_sec, 5)  -0.7208995  SYSTEMPFMSTATISTICS
# 17253   (baserx_avg_1_min_mbps_sec, 6) -0.70721017  SYSTEMPFMSTATISTICS
# 17256   (baserx_avg_1_min_mbps_sec, 9) -0.70996152  SYSTEMPFMSTATISTICS
# 17287  (baserx_avg_5_min_mbps_sec, 15) -0.71135028  SYSTEMPFMSTATISTICS
# 17288  (baserx_avg_5_min_mbps_sec, 16) -0.71523589  SYSTEMPFMSTATISTICS
# 17298   (baserx_avg_5_min_mbps_sec, 4) -0.71647042  SYSTEMPFMSTATISTICS

# %%
corr_filter = (np.abs(corr_all['corr'])>.7) & (1 >= np.abs(corr_all['corr']))
corr_filter = corr_filter & (corr_all['table'] == 'SYSTEMPFMSTATISTICS')
# dates = pd.IndexSlice[:'2022-04-22 04:00']         # optional to zoom
# axvlines=['2022-04-22 01:00', '2022-04-22 04:00']  # optional reference lines

plot_corr(corr_all, corr_filter, IBASIS21, stat_unique)
# Out:
# C:\Users\Viktor\AppData\Local\Temp\ipykernel_12876\3547784964.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c.sort_values('corr', key=np.abs, inplace=True)
# 1 ('baserx_avg_1_min_mbps_sec', '6') SYSTEMPFMSTATISTICS
# 2 ('baserx_avg_1_min_mbps_sec', '9') SYSTEMPFMSTATISTICS
# 3 ('baserx_avg_1_min_mbps_sec', '19') SYSTEMPFMSTATISTICS
# 4 ('baserx_avg_5_min_mbps_sec', '15') SYSTEMPFMSTATISTICS
# 5 ('baserx_avg_5_min_mbps_sec', '16') SYSTEMPFMSTATISTICS
# 6 ('baserx_avg_5_min_mbps_sec', '4') SYSTEMPFMSTATISTICS
# 7 ('baserx_avg_1_min_mbps_sec', '5') SYSTEMPFMSTATISTICS
# 8 ('baserx_avg_1_min_mbps_sec', '4') SYSTEMPFMSTATISTICS
# 9 ('baserx_avg_1_min_mbps_sec', '15') SYSTEMPFMSTATISTICS
# 10 ('baserx_avg_1_min_mbps_sec', '14') SYSTEMPFMSTATISTICS
# 11 ('baserx_avg_1_min_mbps_sec', '16') SYSTEMPFMSTATISTICS

# %% [markdown]
# # Notes not included in _correlator file

# %% [markdown]
# ## hist for some plots

# %%
bins=50
fig, axes = plt.subplots(1,2, figsize=(12, 4))
IBASIS21.plot.hist(bins=bins, ax=axes[0])
stat_unique['SYSTEMPFMSTATISTICS'].loc[:, ('baserx_avg_1_min_mbps_sec', '6')].hist(bins=bins,ax=axes[1])
# Out:
# <AxesSubplot:>

# %%
(-1*IBASIS21).plot()
# Out:
# <AxesSubplot:xlabel='#timeofcollection'>

# %% [markdown]
# ## visualization of diff results

# %%
IBASIS2 = pgwcall.groupby(by=['pgw_name']).get_group('PGW-IBASIS_2')
IBASIS21 = IBASIS2.loc['2022-04-21 21:00':]
# df without trend
IBASIS21nt = IBASIS21.drop(columns=['resourceid', 'zone_name', 'pgw_name']).diff(1)

# %%
df1, df2 = IBASIS21, IBASIS21nt
columns = ['NumCurrentSessions', 'NumGySessions', 'NumLocalCloseAttempts', 
           'NumActiveCurrentSessions', 'NumTotalBearersSetupSuccess', 'NumCreateSessionAttempt',
          'NumSGSNInitUpdatePdpAttempt','NumRatTypeHspaEvoSessions']
fig, axes = plt.subplots(len(columns), 2, figsize=(20, len(columns)*2), sharex=True)
for i, col in enumerate(columns):
    df1[col].plot(ax=axes[i,0], legend=True)
    df2[col].plot(ax=axes[i,1], legend=True)
